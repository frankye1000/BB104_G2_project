# %%
from pymongo import MongoClient
client = MongoClient("mongodb://127.0.0.1:27017")
db = client["<db name>"]

collection = db["<collection name>"]
contents = collection.find({},{"content":1,"_id":0}).limit(100)

liberty_news_cleaned_lsit=[]
for content in contents:
    liberty_news_cleaned_lsit.append(content["content"].split(" "))

# %%
texts = liberty_news_cleaned_lsit

# %%
from gensim import corpora, models
import gensim
# turn our tokenized documents into a id <-> term dictionary
dictionary = corpora.Dictionary(texts)
    
# convert tokenized documents into a document-term matrix
corpus = [dictionary.doc2bow(text) for text in texts]

# generate LDA model
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=40, id2word = dictionary, passes=10)

# %%
dict(dictionary)

# %%
corpus

# %%
import pprint
pprint.pprint(ldamodel.print_topics(num_topics=40, num_words=40))
# Out:
# [(0,
#   '0.056*"中國" + 0.033*"李明哲" + 0.026*"台灣" + 0.017*"人權" + 0.015*"政府" + '
#   '0.013*"川普" + 0.012*"國家" + 0.011*"自由" + 0.009*"人民" + 0.009*"民主" + 0.007*"政治" '
#   '+ 0.007*"人士" + 0.006*"顛覆" + 0.006*"台灣人" + 0.005*"判決" + 0.005*"家屬" + '
#   '0.005*"國際" + 0.005*"救援" + 0.005*"非政府組織" + 0.004*"十九大" + 0.004*"呼籲" + '
#   '0.004*"社會" + 0.004*"權利" + 0.004*"言論" + 0.004*"法律" + 0.004*"五年" + 0.004*"兩岸" '
#   '+ 0.004*"律師" + 0.004*"審判" + 0.004*"組織" + 0.004*"政權罪" + 0.004*"行動" + '
#   '0.003*"無法" + 0.003*"聯合國" + 0.003*"政權" + 0.003*"中共" + 0.003*"強調" + '
#   '0.003*"媒體" + 0.003*"北京" + 0.003*"可能"'),
#  (1,
#   '0.027*"土地" + 0.012*"國有" + 0.010*"規定" + 0.009*"住宅" + 0.008*"使用" + '
#   '0.008*"明年度" + 0.007*"租金" + 0.007*"契約" + 0.006*"王如玄" + 0.006*"政府" + '
#   '0.006*"業者" + 0.006*"中心" + 0.005*"租賃" + 0.005*"優惠" + 0.005*"取得" + 0.005*"管理" '
#   '+ 0.004*"不動產" + 0.004*"登記" + 0.004*"出售" + 0.004*"財政部" + 0.004*"立委" + '
#   '0.004*"部分" + 0.004*"市場" + 0.004*"位於" + 0.004*"占用" + 0.004*"返還" + 0.004*"建物" '
# ...
